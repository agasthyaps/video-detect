# %%
#import packages
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup, SoupStrainer
import boto3
import requests
from sqlalchemy import create_engine

# %%
def has_embedded_video(file, method):
    
    video_flags = ['youtube','video','.mp4','player']
    unless = ['soundcloud']
    html_snippet = []
    
    if method == "s3":
        obj = s3.Object('vpal-link-data','files/'+file)
        soup = BeautifulSoup(obj.get()['Body'].read(),'lxml',parse_only=SoupStrainer("iframe"))
    elif method == "scrape":
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.0; WOW64; rv:24.0) Gecko/20100101 Firefox/24.0' }
        req = requests.get(file, headers = headers)
        page = req.content
        soup = BeautifulSoup(page, 'lxml',parse_only=SoupStrainer("iframe"))
        
    if soup.find("iframe"):
        for frame in soup.find_all("iframe"):
            for key in frame.attrs:
                if any(flag in frame.attrs[key] for flag in video_flags) and any(u not in frame.attrs[key] for u in unless):
                    html_snippet.append(frame)
    
    html_snippet = list(set(html_snippet))               
    hasit = len(html_snippet)
    
    return hasit, html_snippet

# %%
def has_hyperlinked_video(file, method):
    
    video_flags = ['youtube','vimeo']
    html_snippet = []
    
    if method == "s3":
        obj = s3.Object('vpal-link-data','files/'+file)
        soup = BeautifulSoup(obj.get()['Body'].read(),'lxml',parse_only=SoupStrainer("a"))
    elif method == "scrape":
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.0; WOW64; rv:24.0) Gecko/20100101 Firefox/24.0' }
        req = requests.get(file, headers = headers)
        page = req.content
        soup = BeautifulSoup(page, 'lxml',parse_only=SoupStrainer("a"))
        
    if soup.find("a"):
        for a in soup.find_all("a"):
            for key in a.attrs:
                if any(flag in a.attrs[key] for flag in video_flags):
                    html_snippet.append(a)
                    
    html_snippet = list(set(html_snippet))               
    hasit = len(html_snippet)
    
    return hasit, html_snippet

# %%
def prune_df(df):
    bad = ['user','login','pin1','calendar',
       '0%2C0%2C0%2C0%2C0%2C1','0%2C0%2C0%2C0%2C0%2C2','tagged',
       'lang=','/?', 'event/',
       '.aif','.mp3','.gif','.pdf','.gz','.wtt','.mswd','.dd','.key','.ppt','.txt',
       '.ppiv','.m','.ps~','.prev','search','ppframe.htm',
      '.fits','.tgz','.dat','.presentation','.pages','bagelsite','AirlineSite']
    
    msk = [False if any(b in i for b in bad) else True for i in df.url]
    pruned_df = df[msk]
    
    inv_dup_msk = pruned_df.duplicated(subset="checksum")
    pruned_df = pruned_df[~inv_dup_msk]
    
    return pruned_df

# %%
def find_all_videos(data_df,method,logging=False):
#     urls = list(data_df.url)
#     huids = list(data_df.person_id)

    if method == "s3":
        files_or_urls = data_df.id
    elif method == "scrape":
        files_or_urls = data_df.url
        
    num_embedded_videos = []
    num_hyperlinked_videos = []
    embedded_snippet = []
    hyperlinked_snippet = []
    
    total_urls = data_df.shape[0]
    
    # check for videos
    print("beginning search. ({} urls)".format(total_urls))
    
    for ind, file in enumerate(files_or_urls):
        embedded = has_embedded_video(file, method)
        hyperlinked = has_hyperlinked_video(file, method)
        
        num_embedded_videos.append(embedded[0])
        embedded_snippet.append(embedded[1])
        
        num_hyperlinked_videos.append(hyperlinked[0])
        hyperlinked_snippet.append(hyperlinked[1])
        
        if logging and total_urls >= 100:
            pct_done = (ind/total_urls)*100
            if pct_done % 10 == 0:
                print("Done with {}% of urls.".format(pct_done))
                
    print("finished searching all urls.")
    return num_embedded_videos, embedded_snippet, num_hyperlinked_videos, hyperlinked_snippet

# %%
# access database
s3 = boto3.resource('s3')
ssm = boto3.client('ssm',region_name='us-east-1')
db_connection_string = ssm.get_parameter(Name='/link/prod/read/db_connection_string')['Parameter']['Value']
engine = create_engine(db_connection_string)
# person_resource = pd.read_sql_table('person_resource',engine)
link_ent = pd.read_sql_table('link_entity',engine)
link_ent_resource = pd.read_sql_table('link_entity_resources',engine)
resource = pd.read_sql_table('link_resource',engine)
# person_resource.columns = ['person_id','id']
# data = person_resource.merge(resource)

# %%
link_ent.columns = ['entity_id','name','type']

# %%
link_ent_resource.head()
# Out:
#    id                             entity_id  \
# 0   1  fe299ae2-6e37-417f-8544-245b1c37dc58
# 1   2  fe299ae2-6e37-417f-8544-245b1c37dc58
# 2   3  fe299ae2-6e37-417f-8544-245b1c37dc58
# 3   4  fe299ae2-6e37-417f-8544-245b1c37dc58
# 4   5  fe299ae2-6e37-417f-8544-245b1c37dc58
#
#                                 resource_id
# 0  cde57122f81e1972926c488220ec55981b80324e
# 1  b1bded44eab335a615058bdc477746d2dd08b36b
# 2  9e3e28717985df55090a6288e260ddc09f04fb68
# 3  0a9cc22f7b17f3f99d971dec60e0f2efa9608b5c
# 4  936fa927a34af1c4a6fcdae587ef64b66428f44f

# %%
resource.columns = ['resource_id','url','content_type','checksum']

# %%
data = link_ent.merge(link_ent_resource.drop('id',axis=1))

# %%
data = data.merge(resource)

# %%
data.columns = ['entity_id', 'name', 'type', 'id', 'url', 'content_type',
       'checksum']

# %%
not_people = data[data.type != 'person']

# %%
not_people.head()
# Out:
#                               entity_id             name type  \
# 0  f38b5160-e570-4995-8fe2-1d69d37bfc30  Harvard Library
# 1  f38b5160-e570-4995-8fe2-1d69d37bfc30  Harvard Library
# 2  f38b5160-e570-4995-8fe2-1d69d37bfc30  Harvard Library
# 3  f38b5160-e570-4995-8fe2-1d69d37bfc30  Harvard Library
# 4  f38b5160-e570-4995-8fe2-1d69d37bfc30  Harvard Library
#
#                                          id  \
# 0  d2420be2f5bee0221bc3742ad2cac3fe9c9404fa
# 1  13cf1a93e12244d946f089dea724e743c8f8a48b
# 2  c2ef2a6af9837f28078504c4d1f88aed67712844
# 3  c8b9adedf487df9ef7b96fc9be0235c59f870801
# 4  11cd7d9b4b2ce6166ce4a910e9da5e72397bd84e
#
#                                                  url  \
# 0  https://library.harvard.edu/onlineexhibits/sol...
# 1  https://library.harvard.edu/collections/epj/ja...
# 2  https://library.harvard.edu/collections/ipcc/a...
# 3  https://library.harvard.edu/collections/record...
# 4     https://library.harvard.edu/libraries/yenching
#
#                content_type                          checksum
# 0                 text/html  cbd9e687d0fbc07db52396d302eeed1f
# 1                 text/html  e0ee9f82e59efea5371bbe2e1a527f57
# 2                 text/html  ff4e781025eb31f2f79799cbe8a97090
# 3  text/html; charset=UTF-8  63ac61ac59828ed999576f4ca17e4f63
# 4  text/html; charset=UTF-8  56ea2856bc58cf8d3f418951ff8f6c41

# %%
file = not_people.resource_id[0]
obj = s3.Object('vpal-link-data','files/'+file)
soup = BeautifulSoup(obj.get()['Body'].read(),'lxml')
url = not_people.url[0]
url
# Out:
# 'https://library.harvard.edu/onlineexhibits/solti/twentieth/bartok-sonata/index.html'

# %%
entity_ids = not_people.entity_id.unique()

# %%
entity_dict = {}

for i in entity_ids:
    
    temp_df = prune_df(not_people[not_people.entity_id ==i])
    temp_vids = find_all_videos(temp_df, method = "s3")
    temp_df['num_embedded'] = temp_vids[0]
    temp_df['embedded_html'] = temp_vids[1]
    temp_df['num_hyperlinked'] = temp_vids[2]
    temp_df['hyperlinked_html'] = temp_vids[3]
    temp_df['total_videos'] = temp_df.num_embedded + temp_df.num_hyperlinked
    temp_df = temp_df[['entity_id','url','total_videos','num_embedded','embedded_html','num_hyperlinked','hyperlinked_html']]
    
    entity_dict[i] = temp_df
    del temp_df
# Out:
# beginning search. (401 urls)
# finished searching all urls.
# beginning search. (162 urls)
# finished searching all urls.
# beginning search. (70 urls)
# finished searching all urls.
# beginning search. (22 urls)
# finished searching all urls.
# beginning search. (149 urls)
# finished searching all urls.
# beginning search. (512 urls)
# finished searching all urls.
# beginning search. (123 urls)
# finished searching all urls.
# beginning search. (15 urls)
# finished searching all urls.
# beginning search. (134 urls)
# finished searching all urls.
# beginning search. (13 urls)
# finished searching all urls.
# beginning search. (116 urls)
# finished searching all urls.
# beginning search. (113 urls)
# finished searching all urls.
# beginning search. (887 urls)
# finished searching all urls.
# beginning search. (887 urls)
# finished searching all urls.
# beginning search. (104 urls)
# finished searching all urls.
# beginning search. (128 urls)
# finished searching all urls.
# beginning search. (641 urls)
# finished searching all urls.
# beginning search. (150 urls)
# finished searching all urls.
# beginning search. (217 urls)
# finished searching all urls.
# beginning search. (75 urls)
# finished searching all urls.
# beginning search. (117 urls)
# finished searching all urls.
# beginning search. (140 urls)
# finished searching all urls.
# beginning search. (161 urls)
# finished searching all urls.
# beginning search. (123 urls)
# finished searching all urls.
# beginning search. (115 urls)
# finished searching all urls.
# beginning search. (115 urls)
# finished searching all urls.
# beginning search. (102 urls)
# finished searching all urls.
# beginning search. (114 urls)
# finished searching all urls.
# beginning search. (195 urls)
# finished searching all urls.
# beginning search. (67 urls)
# finished searching all urls.
# beginning search. (115 urls)
# finished searching all urls.
# beginning search. (159 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (90 urls)
# finished searching all urls.
# beginning search. (30 urls)
# finished searching all urls.
# beginning search. (737 urls)
# finished searching all urls.
# beginning search. (1053 urls)
# finished searching all urls.
# beginning search. (119 urls)
# finished searching all urls.
# beginning search. (106 urls)
# finished searching all urls.
# beginning search. (134 urls)
# finished searching all urls.
# beginning search. (97 urls)
# finished searching all urls.
# beginning search. (107 urls)
# finished searching all urls.
# beginning search. (91 urls)
# finished searching all urls.
# beginning search. (25 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (107 urls)
# finished searching all urls.
# beginning search. (94 urls)
# finished searching all urls.
# beginning search. (4 urls)
# finished searching all urls.
# beginning search. (5 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (150 urls)
# finished searching all urls.
# beginning search. (2426 urls)
# finished searching all urls.
# beginning search. (132 urls)
# finished searching all urls.
# beginning search. (2842 urls)
# finished searching all urls.
# beginning search. (4 urls)
# finished searching all urls.
# beginning search. (4 urls)
# finished searching all urls.
# beginning search. (80 urls)
# finished searching all urls.
# beginning search. (88 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (96 urls)
# finished searching all urls.
# beginning search. (98 urls)
# finished searching all urls.
# beginning search. (82 urls)
# finished searching all urls.
# beginning search. (97 urls)
# finished searching all urls.
# beginning search. (162 urls)
# finished searching all urls.
# beginning search. (86 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (128 urls)
# finished searching all urls.
# beginning search. (91 urls)
# finished searching all urls.
# beginning search. (147 urls)
# finished searching all urls.
# beginning search. (8 urls)
# finished searching all urls.
# beginning search. (137 urls)
# finished searching all urls.
# beginning search. (44 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (120 urls)
# finished searching all urls.
# beginning search. (140 urls)
# finished searching all urls.
# beginning search. (81 urls)
# finished searching all urls.
# beginning search. (84 urls)
# finished searching all urls.
# beginning search. (5 urls)
# finished searching all urls.
# beginning search. (96 urls)
# finished searching all urls.
# beginning search. (8 urls)
# finished searching all urls.
# beginning search. (85 urls)
# finished searching all urls.
# beginning search. (47 urls)
# finished searching all urls.
# beginning search. (123 urls)
# finished searching all urls.
# beginning search. (111 urls)
# finished searching all urls.
# beginning search. (140 urls)
# finished searching all urls.
# beginning search. (130 urls)
# finished searching all urls.
# beginning search. (34 urls)
# finished searching all urls.
# beginning search. (820 urls)
# finished searching all urls.
# beginning search. (382 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (96 urls)
# finished searching all urls.
# beginning search. (101 urls)
# finished searching all urls.
# beginning search. (124 urls)
# finished searching all urls.
# beginning search. (113 urls)
# finished searching all urls.
# beginning search. (125 urls)
# finished searching all urls.
# beginning search. (3 urls)
# finished searching all urls.
# beginning search. (30 urls)
# finished searching all urls.
# beginning search. (52 urls)
# finished searching all urls.
# beginning search. (116 urls)
# finished searching all urls.
# beginning search. (108 urls)
# finished searching all urls.
# beginning search. (96 urls)
# finished searching all urls.
# beginning search. (41 urls)
# finished searching all urls.
# beginning search. (11 urls)
# finished searching all urls.
# beginning search. (93 urls)
# finished searching all urls.
# beginning search. (85 urls)
# finished searching all urls.
# beginning search. (70 urls)
# finished searching all urls.
# beginning search. (39 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (120 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (18 urls)
# finished searching all urls.
# beginning search. (82 urls)
# finished searching all urls.
# beginning search. (12 urls)
# finished searching all urls.
# beginning search. (1218 urls)
# finished searching all urls.
# beginning search. (144 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (66 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (5 urls)
# finished searching all urls.
# beginning search. (3 urls)
# finished searching all urls.
# beginning search. (1314 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (141 urls)
# finished searching all urls.
# beginning search. (35 urls)
# finished searching all urls.
# beginning search. (254 urls)
# finished searching all urls.
# beginning search. (99 urls)
# finished searching all urls.
# beginning search. (119 urls)
# finished searching all urls.
# beginning search. (106 urls)
# finished searching all urls.
# beginning search. (130 urls)
# finished searching all urls.
# beginning search. (99 urls)
# finished searching all urls.
# beginning search. (94 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (129 urls)
# finished searching all urls.
# beginning search. (70 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (105 urls)
# finished searching all urls.
# beginning search. (134 urls)
# finished searching all urls.
# beginning search. (66 urls)
# finished searching all urls.
# beginning search. (124 urls)
# finished searching all urls.
# beginning search. (10 urls)
# finished searching all urls.
# beginning search. (125 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (28 urls)
# finished searching all urls.
# beginning search. (980 urls)
# finished searching all urls.
# beginning search. (22 urls)
# finished searching all urls.
# beginning search. (130 urls)
# finished searching all urls.
# beginning search. (115 urls)
# finished searching all urls.
# beginning search. (77 urls)
# finished searching all urls.
# beginning search. (420 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (129 urls)
# finished searching all urls.
# beginning search. (101 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (159 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (24 urls)
# finished searching all urls.
# beginning search. (934 urls)
# finished searching all urls.
# beginning search. (256 urls)
# finished searching all urls.
# beginning search. (630 urls)
# finished searching all urls.
# beginning search. (29 urls)
# finished searching all urls.
# beginning search. (16 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (112 urls)
# finished searching all urls.
# beginning search. (150 urls)
# finished searching all urls.
# beginning search. (68 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (41 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (114 urls)
# finished searching all urls.
# beginning search. (26 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (56 urls)
# finished searching all urls.
# beginning search. (2449 urls)
# finished searching all urls.
# beginning search. (30 urls)
# finished searching all urls.
# beginning search. (50 urls)
# finished searching all urls.
# beginning search. (109 urls)
# finished searching all urls.
# beginning search. (112 urls)
# finished searching all urls.
# beginning search. (83 urls)
# /Users/agp234/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.cfa.harvard.edu/dvl/special/pubaff/20070920.rm
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# finished searching all urls.
# beginning search. (126 urls)
# finished searching all urls.
# beginning search. (5 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (130 urls)
# finished searching all urls.
# beginning search. (137 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (11 urls)
# finished searching all urls.
# beginning search. (481 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (608 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (8 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (8 urls)
# finished searching all urls.
# beginning search. (66 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (21 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (5 urls)
# finished searching all urls.
# beginning search. (126 urls)
# finished searching all urls.
# beginning search. (130 urls)
# finished searching all urls.
# beginning search. (132 urls)
# finished searching all urls.
# beginning search. (918 urls)
# finished searching all urls.
# beginning search. (1226 urls)
# finished searching all urls.
# beginning search. (122 urls)
# finished searching all urls.
# beginning search. (148 urls)
# finished searching all urls.
# beginning search. (152 urls)
# finished searching all urls.
# beginning search. (148 urls)
# finished searching all urls.
# beginning search. (125 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (71 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (151 urls)
# finished searching all urls.
# beginning search. (105 urls)
# finished searching all urls.
# beginning search. (30 urls)
# finished searching all urls.
# beginning search. (107 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (2 urls)
# finished searching all urls.
# beginning search. (30 urls)
# finished searching all urls.
# beginning search. (116 urls)
# finished searching all urls.
# beginning search. (367 urls)
# finished searching all urls.
# beginning search. (119 urls)
# finished searching all urls.
# beginning search. (811 urls)
# finished searching all urls.
# beginning search. (70 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (17 urls)
# finished searching all urls.
# beginning search. (436 urls)
# finished searching all urls.
# beginning search. (17 urls)
# finished searching all urls.
# beginning search. (27 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (6 urls)
# finished searching all urls.
# beginning search. (3 urls)
# finished searching all urls.
# beginning search. (4 urls)
# finished searching all urls.
# beginning search. (5 urls)
# finished searching all urls.
# beginning search. (67 urls)
# finished searching all urls.
# beginning search. (11 urls)
# finished searching all urls.
# beginning search. (8 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (63 urls)
# finished searching all urls.
# beginning search. (18 urls)
# finished searching all urls.
# beginning search. (9 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (44 urls)
# finished searching all urls.
# beginning search. (3 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (110 urls)
# finished searching all urls.
# beginning search. (3 urls)
# finished searching all urls.
# beginning search. (55 urls)
# finished searching all urls.
# beginning search. (5 urls)
# finished searching all urls.
# beginning search. (542 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (390 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (814 urls)
# finished searching all urls.
# beginning search. (4 urls)
# finished searching all urls.
# beginning search. (92 urls)
# finished searching all urls.
# beginning search. (74 urls)
# finished searching all urls.
# beginning search. (196 urls)
# finished searching all urls.
# beginning search. (46 urls)
# finished searching all urls.
# beginning search. (5 urls)
# finished searching all urls.
# beginning search. (171 urls)
# finished searching all urls.
# beginning search. (5 urls)
# finished searching all urls.
# beginning search. (303 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (161 urls)
# finished searching all urls.
# beginning search. (1771 urls)
# finished searching all urls.
# beginning search. (338 urls)
# finished searching all urls.
# beginning search. (283 urls)
# finished searching all urls.
# beginning search. (879 urls)
# finished searching all urls.
# beginning search. (102 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (42 urls)
# finished searching all urls.
# beginning search. (2 urls)
# finished searching all urls.
# beginning search. (28 urls)
# finished searching all urls.
# beginning search. (257 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (511 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (42 urls)
# finished searching all urls.
# beginning search. (135 urls)
# finished searching all urls.
# beginning search. (114 urls)
# finished searching all urls.
# beginning search. (195 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (15 urls)
# finished searching all urls.
# beginning search. (971 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (135 urls)
# finished searching all urls.
# beginning search. (109 urls)
# finished searching all urls.
# beginning search. (2 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (88 urls)
# finished searching all urls.
# beginning search. (854 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (130 urls)
# finished searching all urls.
# beginning search. (19 urls)
# finished searching all urls.
# beginning search. (7 urls)
# finished searching all urls.
# beginning search. (152 urls)
# finished searching all urls.
# beginning search. (394 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (7 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (396 urls)
# finished searching all urls.
# beginning search. (140 urls)
# finished searching all urls.
# beginning search. (194 urls)
# finished searching all urls.
# beginning search. (150 urls)
# finished searching all urls.
# beginning search. (40 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (2 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (138 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (97 urls)
# finished searching all urls.
# beginning search. (163 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (120 urls)
# finished searching all urls.
# beginning search. (65 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (1293 urls)
# finished searching all urls.
# beginning search. (30 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (144 urls)
# finished searching all urls.
# beginning search. (5 urls)
# finished searching all urls.
# beginning search. (175 urls)
# finished searching all urls.
# beginning search. (1093 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (66 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (169 urls)
# finished searching all urls.
# beginning search. (108 urls)
# finished searching all urls.
# beginning search. (526 urls)
# finished searching all urls.
# beginning search. (10 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (24 urls)
# finished searching all urls.
# beginning search. (17 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (0 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (177 urls)
# finished searching all urls.
# beginning search. (100 urls)
# finished searching all urls.
# beginning search. (117 urls)
# finished searching all urls.
# beginning search. (98 urls)
# finished searching all urls.
# beginning search. (85 urls)
# finished searching all urls.
# beginning search. (1 urls)
# finished searching all urls.
# beginning search. (47 urls)
# finished searching all urls.
# beginning search. (91 urls)
# finished searching all urls.
# beginning search. (65 urls)
# finished searching all urls.
# beginning search. (58 urls)
# finished searching all urls.

# %%
# entity_dict['f38b5160-e570-4995-8fe2-1d69d37bfc30'][entity_dict['f38b5160-e570-4995-8fe2-1d69d37bfc30']['total_videos'] > 0]

# %%
final_entity_data = pd.concat([df for df in entity_dict.values()], ignore_index=True)

# %%
not_people.shape
# Out:
# (75635, 7)

# %%
final_entity_data.to_csv('data/entity_videos.csv')

# %%
# person bio
# data = pd.read_csv('data/person_resource.csv')

# %%
fac = 40809295

# %%
faculty_dict = {}
faculty_ids = data.person_id.unique()
file = open("log.txt","w")

for i in faculty_ids:
    
    file.write(i)
    temp_df = prune_df(data[data.person_id ==i])
    try:
        temp_vids = find_all_videos(temp_df, method = "scrape")
    except 
    temp_df['num_embedded'] = temp_vids[0]
    temp_df['embedded_html'] = temp_vids[1]
    temp_df['num_hyperlinked'] = temp_vids[2]
    temp_df['hyperlinked_html'] = temp_vids[3]
    temp_df['total_videos'] = temp_df.num_embedded + temp_df.num_hyperlinked
    temp_df = temp_df[['person_id','url','total_videos','num_embedded','embedded_html','num_hyperlinked','hyperlinked_html']]
    
    faculty_dict[i] = temp_df
    del temp_df
    file.write("\n")

file.close()
# Out:
# beginning search. (318 urls)
# finished searching all urls.

# %%
faculty_dict = {}
faculty_ids = data.person_id.unique()
file = open("log.txt","w") 
for i in faculty_ids:
    file.write(i)
    temp_df = prune_df(data[data.person_id == i])
    temp_vids = find_all_videos(temp_df, method = "scrape")
    temp_df['num_videos'] = temp_vids
    temp_df = temp_df[['person_id','url','num_videos']]
    
    faculty_dict[i] = temp_df
    del temp_df
file.close()

# %%
dfx = pd.concat([df for df in faculty_dict.values()], ignore_index=True)

# %%
dfx.to_csv('data/partiallycomplete.csv')

# %%
# data.to_csv('data/person_resource.csv')

# %%
# videos = find_all_videos(data,logging=True)
# data['num_videos'] = videos
# final_df = data[['person_id','url','num_videos']]

# %%
faculty_ids = data.person_id.unique()
[i for i,j in enumerate(faculty_ids) if j == 40448225]
# Out:
# [258]

# %%
for i in data.person_id.unique():
    if prune_df(data[data.person_id == i]).shape[0] == 741:
        print(i)
# Out:
# 40652299

# %%
data[data.person_id == 40652299]
# Out:
#        Unnamed: 0  person_id                                        id  \
# 28795       28795   40652299  7041d641c3c541ffa2e352903ad93177571a96ed
# 28796       28796   40652299  c225045beb4e8b2c1805d33727571b2c755b9f47
# 28797       28797   40652299  000bca766d36a3e3bf418e7520be1bf0df8733bf
# 28798       28798   40652299  2871f778c22c41093795e0ece2745c9ff9960c5e
# 28799       28799   40652299  f685f80d1aa38ec128d8630d392a5f447a918503
# 28800       28800   40652299  61b6a12e1036ef86274276ee6e7c235c3d55e78e
# 28801       28801   40652299  d1f55589708048a8e330e7d14ebdea9cb60ad81a
# 28802       28802   40652299  96a1a8193f74bec4cd55d7f0c1b131377fe0193f
# 28803       28803   40652299  2667616b40104d00b227ed3a5580f5ff9aae86ca
# 28804       28804   40652299  d76ce1adc5daa012fd78a11cf5d4c9d7647e7549
# 28805       28805   40652299  c1b0f10542cb131c942549a7b8d36375269363ce
# 28806       28806   40652299  4eaa42935a8e255ad1af721817121f2eb694d6e9
# 28807       28807   40652299  e9a100892c1b51ee86596ff30af1f5bec988b6f5
# 28808       28808   40652299  52cb59c022fc8f1be69781cf1ba57344c3e4f6d6
# 28809       28809   40652299  102d9794957c6129512b75196be0011d2788e85c
# 28810       28810   40652299  e27d00b8a64d88c5aa63dc0e4a786ee6464c2c32
# 28811       28811   40652299  9794aac95ccbb91fd1b6acbc0e681f5a74ba55d7
# 28812       28812   40652299  db1b669e35cbf0ea14815896349c60a2d29435e3
# 28813       28813   40652299  9cc91f1101e67c036995476a15f494247478e1e1
# 28814       28814   40652299  3793cb57564c3ba8ab6bd079ce3e58981fc62c8f
# 28815       28815   40652299  8d828e34e45c7ae661f931e73655f4c5da66777b
# 28816       28816   40652299  fd9fe8785221e698a056b74c6be09af86aacde41
# 28817       28817   40652299  215eaa4b581610c8000bffd62709926a7266a037
# 28818       28818   40652299  de50e840a6374e06293f7b878e3c4559befb0d0d
# 28819       28819   40652299  ead5a3b8825d016d5918757964aa973cf9335837
# 28820       28820   40652299  63dab4285c94c2ca962ad0d73168ce7bca3472c5
# 28821       28821   40652299  d850194863d02b79e6c4faf256766b773f8714ec
# 28822       28822   40652299  2f04c4448ddbb59d2341afd13b2589eed3fc606b
# 28823       28823   40652299  c6832b84fe778c3f0469cde83441e2bac043a0ac
# 28824       28824   40652299  31db10ddf68a5ea21e842620ec152a9725942c91
# ...           ...        ...                                       ...
# 29539       29539   40652299  9f7159c58613a040ae302622d02ee6f4a1d675ad
# 29540       29540   40652299  04013a97a47cca77d23de32c9e580b1f021f8866
# 29541       29541   40652299  d11c65812f1bf0e4b6759dc6fe4f710813811807
# 29542       29542   40652299  792bad47d0700eaf35c3cc6c8b3183b6576a7e70
# 29543       29543   40652299  79321378155d61163e5ac0d79fed6c32894cc4fa
# 29544       29544   40652299  650281f47c7b1db5ef17822eda4a3895e81efe6e
# 29545       29545   40652299  a94f21dccfeec860d311f609788652344e09a134
# 29546       29546   40652299  1990556f9140214504757942545fb96701d5f1d9
# 29547       29547   40652299  a1d4942051b0818799a0391db38bc8ae9576066e
# 29548       29548   40652299  0b9bbf1178e9c3ed3b91d73b3277619eb81bebe3
# 29549       29549   40652299  383287e73bb2e3d9657bbda15c62ba897eb99572
# 29550       29550   40652299  bb30649a44edba9339d990e6e131087f3be70c92
# 29551       29551   40652299  dcc03ef6dd74ee20687c810cb07754a3900a5e84
# 29552       29552   40652299  57cb14a36075c7143b8a67bed209707c8e2aaf40
# 29553       29553   40652299  6036837445d22815bfd5e3578b333d442c266154
# 29554       29554   40652299  332b5d841ec117cb63121b330dfa8778f85ee505
# 29555       29555   40652299  6fa104df999eb01826c766bf2f1e5f599470e89c
# 29556       29556   40652299  9f3845c3b85dd2569257557d9f717996cf9b98bb
# 29557       29557   40652299  dfaa3a44bcaee5dd93655e1cad73d5aebfeacda8
# 29558       29558   40652299  5c9b6a3b802438814410d1359f6a8e7bf3379381
# 29559       29559   40652299  663aa6ef5fe7e80cab1b9283138671a869ef9ca2
# 29560       29560   40652299  cbbab76e0a0af434113bd8135e856962c0205d38
# 29561       29561   40652299  0d894e23ce06778ae7999daeec0a60c79343bfe5
# 29562       29562   40652299  3ed831629cd49e6c25d405bab22554e65af251e9
# 29563       29563   40652299  8db4b0b94a4b27be09de45a41539fd6f43122b71
# 29564       29564   40652299  f62e334d80824aff634b7937cac0a9d48b0c7dd0
# 29565       29565   40652299  28067d7e78e17374066ef2d6e1449e06e0d42490
# 29566       29566   40652299  68a395c39e3955e19e4e4bbba1dd2879f29feacc
# 29567       29567   40652299  19b1f334c3a280a3c129dce6ebe81b4c2c855bea
# 29568       29568   40652299  26812f55d7c83e02c3b6af0eb63192ad9b2c2fe9
#
#                                                      url  \
# 28795                      https://vcg.seas.harvard.edu/
# 28796  https://vcg.seas.harvard.edu/publications/comm...
# 28797  https://vcg.seas.harvard.edu/publications/comm...
# 28798  https://vcg.seas.harvard.edu/publications/seq2...
# 28799             https://vcg.seas.harvard.edu/made-with
# 28800  https://vcg.seas.harvard.edu/publications/seq2...
# 28801  https://vcg.seas.harvard.edu/publications/hybr...
# 28802  https://vcg.seas.harvard.edu/publications/comm...
# 28803  https://vcg.seas.harvard.edu/publications/hybr...
# 28804  https://vcg.seas.harvard.edu/publications/eval...
# 28805  https://vcg.seas.harvard.edu/publications/eval...
# 28806  https://vcg.seas.harvard.edu/publications?cate...
# 28807  https://vcg.seas.harvard.edu/publications/dxr-...
# 28808  https://vcg.seas.harvard.edu/publications/seq2...
# 28809  https://vcg.seas.harvard.edu/publications/dxr-...
# 28810  https://vcg.seas.harvard.edu/publications?cate...
# 28811             https://vcg.seas.harvard.edu/code-data
# 28812               https://vcg.seas.harvard.edu/contact
# 28813               https://vcg.seas.harvard.edu/classes
# 28814          https://vcg.seas.harvard.edu/publications
# 28815              https://vcg.seas.harvard.edu/projects
# 28816                https://vcg.seas.harvard.edu/people
# 28817  https://vcg.seas.harvard.edu/publications/scal...
# 28818  https://vcg.seas.harvard.edu/publications/scal...
# 28819  https://vcg.seas.harvard.edu/publications/spar...
# 28820  https://vcg.seas.harvard.edu/publications/an-e...
# 28821  https://vcg.seas.harvard.edu/publications/an-e...
# 28822  https://vcg.seas.harvard.edu/publications/real...
# 28823  https://vcg.seas.harvard.edu/publications/an-e...
# 28824  https://vcg.seas.harvard.edu/publications/dxr-...
# ...                                                  ...
# 29539  https://vcg.seas.harvard.edu/publications/stat...
# 29540  https://vcg.seas.harvard.edu/publications/stat...
# 29541  https://vcg.seas.harvard.edu/publications/stat...
# 29542  https://vcg.seas.harvard.edu/publications/spar...
# 29543  https://vcg.seas.harvard.edu/publications/a-su...
# 29544  https://vcg.seas.harvard.edu/publications/vesi...
# 29545  https://vcg.seas.harvard.edu/publications/abst...
# 29546  https://vcg.seas.harvard.edu/publications/abst...
# 29547      https://vcg.seas.harvard.edu/publications.bib
# 29548  https://vcg.seas.harvard.edu/publications/expl...
# 29549  https://vcg.seas.harvard.edu/publications?cate...
# 29550  https://vcg.seas.harvard.edu/publications?cate...
# 29551  https://vcg.seas.harvard.edu/publications?cate...
# 29552  https://vcg.seas.harvard.edu/publications?cate...
# 29553  https://vcg.seas.harvard.edu/publications/spar...
# 29554  https://vcg.seas.harvard.edu/publications/stat...
# 29555  https://vcg.seas.harvard.edu/publications/stat...
# 29556  https://vcg.seas.harvard.edu/publications/spar...
# 29557  https://vcg.seas.harvard.edu/publications?cate...
# 29558  https://vcg.seas.harvard.edu/publications?cate...
# 29559  https://vcg.seas.harvard.edu/publications/a-su...
# 29560  https://vcg.seas.harvard.edu/publications?cate...
# 29561  https://vcg.seas.harvard.edu/publications?cate...
# 29562  https://vcg.seas.harvard.edu/publications?cate...
# 29563  https://vcg.seas.harvard.edu/publications/abst...
# 29564  https://vcg.seas.harvard.edu/publications/stat...
# 29565  https://vcg.seas.harvard.edu/publications/stat...
# 29566  https://vcg.seas.harvard.edu/publications/stat...
# 29567  https://vcg.seas.harvard.edu/publications/inte...
# 29568  https://vcg.seas.harvard.edu/publications/rhoa...
#
#                               content_type                          checksum
# 28795                            text/html  8dd1be5b89c66471d619aa051ffcd96d
# 28796  application/x-bibtex; charset=UTF-8  5773ac71b2b84174a0d8ce437e3b43f4
# 28797                            text/html  29f2acc08562d92c1c3596f04bbe73bf
# 28798  application/x-bibtex; charset=UTF-8  2696aefd0aac96008a560f3bf5d9bfb6
# 28799                            text/html  c6c40e252830013031d38e605338f21c
# 28800                            text/html  b85220e3b1d9f71a9ffe86349709ec5b
# 28801  application/x-bibtex; charset=UTF-8  d6a7e7ce5cea6ea8ebb40662b1e69eea
# 28802       application/pdf; charset=UTF-8  b32e489b1917bd770be848bec44983ca
# 28803                            text/html  582bbfd3e683ba7209604c3ab936846b
# 28804                            text/html  f168d7c07114aef85176934f91916fa7
# 28805  application/x-bibtex; charset=UTF-8  8d19e48b88deb2c00b6bafcc528a209e
# 28806                            text/html  b2f0fa2823672d28dc67f24f495a2302
# 28807  application/x-bibtex; charset=UTF-8  bfed40ed9e45125fe88914f2f551b062
# 28808       application/pdf; charset=UTF-8  4f11f8da18e5eedb577949aa688e7f43
# 28809                            text/html  48d4a9ed0926f58c2d1059c40a9a7e82
# 28810                            text/html  32eeb87809d710a3be1d1a583ea6b9fb
# 28811                            text/html  294f5f01d8473c6c283079910aa8af73
# 28812                            text/html  a3f934d96e42b90501ef2ac886d56825
# 28813                            text/html  b91e7c4422adcf947e6a0e5bfbecb4ec
# 28814                            text/html  7833780a0b46e7ecffbf0acedd503d84
# 28815                            text/html  0b68c856443ca0097d887e2c8f052ac1
# 28816                            text/html  955d61f3fd0ecacb52bca9a0f6d16820
# 28817  application/x-bibtex; charset=UTF-8  b75010e170a1abbdafdefd735c62d469
# 28818                            text/html  d7561c3a1068a1d5c0c46ee76f947fdb
# 28819  application/x-bibtex; charset=UTF-8  4ff791ba9645b06a781161f5e6f2f9f8
# 28820  application/x-bibtex; charset=UTF-8  44e2410f38664e83faeab25e0cdfb098
# 28821       application/pdf; charset=UTF-8  9d6bf164dcb663b25f788a798dfff6d2
# 28822  application/x-bibtex; charset=UTF-8  83b329d1b23543ed20574bfe7e830298
# 28823                            text/html  4b7874ef3d882bd210cb2251774dd7e0
# 28824       application/pdf; charset=UTF-8  c72c0ab9f43bc9f607da85d021ffff9c
# ...                                    ...                               ...
# 29539  application/x-bibtex; charset=UTF-8  a94c1c8402aaf75750bad385dc7f8496
# 29540                            text/html  ccafb8b1782ec0eb36260969bc862b57
# 29541                            text/html  e62d21190ad1b102113a25cb643725ef
# 29542                            text/html  4ecf326d57f652419d60a001b761fc6d
# 29543       application/pdf; charset=UTF-8  c5d5107ae59f85dab7c014117577d516
# 29544       application/pdf; charset=UTF-8  526ef52b20429582412c29c8bf10a6a1
# 29545  application/x-bibtex; charset=UTF-8  c1955b8a8f7f9614ef1eaf45c49c7ce5
# 29546                            text/html  7ca1693abb7a02e098bc859bb8ddb2b9
# 29547  application/x-bibtex; charset=UTF-8  d80e2dcf96896b728d7393fd5d9ad0dc
# 29548       application/pdf; charset=UTF-8  27c803824ccfda56159a204484724931
# 29549                            text/html  9fbc3f6a7d8b1523414ac4be196f02cf
# 29550                            text/html  9d8366b05a51a62261f345cffaa43c2b
# 29551                            text/html  7a00dce90a30fc4a2a751910d9df3531
# 29552                            text/html  5e57c88810488978842bccac483d0daa
# 29553       application/pdf; charset=UTF-8  eddc52dd06674843c8b3d8e193085dfc
# 29554       application/pdf; charset=UTF-8  bf36679f22415f3a74400d8e329fd465
# 29555       application/pdf; charset=UTF-8  bf36679f22415f3a74400d8e329fd465
# 29556       application/pdf; charset=UTF-8  cd1e4056a4df48d532d9ffadfcd86925
# 29557                            text/html  fadda40918c6b72cb16ebb883eee874b
# 29558                            text/html  8f97f1e3b94a9dd0a97045cc31b3805c
# 29559       application/pdf; charset=UTF-8  c5d5107ae59f85dab7c014117577d516
# 29560                            text/html  cb41fcfc0874c2661d4883534ce0f31d
# 29561                            text/html  768411a5244bb05abe6be34566b67c5c
# 29562                            text/html  46ce41899812416c3e6ace799bffcde5
# 29563       application/pdf; charset=UTF-8  724f325a2a3413b673cae56708135be0
# 29564       application/pdf; charset=UTF-8  bf36679f22415f3a74400d8e329fd465
# 29565       application/pdf; charset=UTF-8  bf36679f22415f3a74400d8e329fd465
# 29566       application/pdf; charset=UTF-8  bf36679f22415f3a74400d8e329fd465
# 29567       application/pdf; charset=UTF-8  82788b9b69f7f47debb17fd3b1755d0c
# 29568       application/pdf; charset=UTF-8  22ec05d9dd7858c143c20c53a8594bcc
#
# [774 rows x 6 columns]

# %%
import csv

with open('csvfile.csv','w',newline='') as csvheader:
    spamwriter = csv.writer(csvheader, delimiter=',')
    spamwriter.writerow(data.columns)

# %%
with open('csvfile.csv','a',newline='') as csvfile:
    spamwriter2 = csv.writer(csvfile, delimiter=',')
    spamwriter2.writerows((data.iloc[i] for i  in range(data.iloc[11:14].shape[0])))

# %%
test = pd.read_csv('data/error_at_90810898.csv')

# %%
link_ent.to_csv('data/link_entity.csv')
